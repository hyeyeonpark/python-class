# %% [markdown]
# <a href="https://colab.research.google.com/github/hyeyeonpark/python-class/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 얼굴 인식 프로그램 

import matplotlib.pyplot as plt # 그림과 관련된 모듈
import matplotlib.image as mpimg # 사진과 관련된 모듈 2

#웹상에서 그림을 나타내는 명령_생략가능 
# %matplotlib inline

# %%
# 분석할 사진 읽어오기

img = mpimg.imread('kim.jpg')

#사진 띄워주기

plt.figure(figsize=(10,8))
plt.imshow(img)
plt.show() #로컬에서 생략 가능

# %%
import requests # 인터넷 연결 데이터 전송

client_id = "W8iChb92KOMSuLawtSBT"
client_secret = "e3nHlg1okG"

url = "https://openapi.naver.com/v1/vision/face" # // 얼굴감지
# url = "https://openapi.naver.com/v1/vision/celebrity" #// 유명인 연예인 닮은얼굴인식
files = {'image': open('kim.jpg', 'rb')}

headers = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret }
response = requests.post(url,  files=files, headers=headers)

detect = json.loads(response.text)

# %%
import json 

# 제이손 형식을 분석하는 모듈


# parsed = json.loads(response.text)
# print(json.dumps(parsed, indent = 4, sort_keys=False ,ensure_ascii=False))

# %%
detect.keys()
# Out:
# dict_keys(['info', 'faces'])

# %%
detect['faces']
# Out:
# [{'age': {'confidence': 0.441697, 'value': '30~34'},
#   'emotion': {'confidence': 1.0, 'value': 'neutral'},
#   'gender': {'confidence': 0.999998, 'value': 'male'},
#   'landmark': {'leftEye': {'x': 298, 'y': 124},
#    'leftMouth': {'x': 297, 'y': 182},
#    'nose': {'x': 320, 'y': 157},
#    'rightEye': {'x': 350, 'y': 129},
#    'rightMouth': {'x': 343, 'y': 186}},
#   'pose': {'confidence': 0.991977, 'value': 'frontal_face'},
#   'roi': {'height': 113, 'width': 113, 'x': 272, 'y': 98}}]

# %%
detect['faces'][0]
# Out:
# {'age': {'confidence': 0.441697, 'value': '30~34'},
#  'emotion': {'confidence': 1.0, 'value': 'neutral'},
#  'gender': {'confidence': 0.999998, 'value': 'male'},
#  'landmark': {'leftEye': {'x': 298, 'y': 124},
#   'leftMouth': {'x': 297, 'y': 182},
#   'nose': {'x': 320, 'y': 157},
#   'rightEye': {'x': 350, 'y': 129},
#   'rightMouth': {'x': 343, 'y': 186}},
#  'pose': {'confidence': 0.991977, 'value': 'frontal_face'},
#  'roi': {'height': 113, 'width': 113, 'x': 272, 'y': 98}}

# %%
detect['faces'][0]['roi']
# Out:
# {'height': 113, 'width': 113, 'x': 272, 'y': 98}

# %%
detect['faces'][0]['gender']
# Out:
# {'confidence': 0.999998, 'value': 'male'}

# %%
detect['faces'][0]['age']
# Out:
# {'confidence': 0.441697, 'value': '30~34'}

# %%
detect['faces'][0]['emotion']
# Out:
# {'confidence': 1.0, 'value': 'neutral'}

# %%
x,y,w,h = detect['faces'][0]['roi'].values()
gender, gen_conf = detect['faces'][0]['gender'].values()
emotion, emotion_conf = detect['faces'][0]['emotion'].values()
age, age_conf = detect['faces'][0]['age'].values()

# %%
annotation = gender + ':' + str(gen_conf) +'\n'+ emotion + ':' + str(emotion_conf) +'\n' + age + ':' + str(age_conf)
print(annotation)
# Out:
# male:0.999998
# neutral:1.0
# 30~34:0.441697

# %%
import matplotlib.patches as patches

img = mpimg.imread('kim.jpg')

fig,ax = plt.subplots(figsize = (10,10))
ax.imshow(img)
re_face = patches.Rectangle((x,y),w,h, linewidth = 5, edgecolor ='r',facecolor ='none')

ax.add_patch(re_face)
plt.text(10,400,annotation, wrap = True, fontsize = 17, color = 'white')
# Out:
# Text(10, 400, 'male:0.999998\nneutral:1.0\n30~34:0.441697')
